# %%
import pandas as pd

# Define the course dataset including electives and prerequisites
courses = [
    ["CSCI151", "Intro to Computer Science I", 4, "", "Core", 100, "fall", 1 ],
    ["CSCI152", "Intro to Computer Science II", 4, "CSCI151", "Core", 100, "spring", 1 ],
    ["CSCI257", "Object-Oriented Programming", 4, "CSCI152", "Core", 100, "fall", 2 ],
    ["CSCI258", "Data Structures and Algorithms", 4, "CSCI257", "Core", 100, "spring",2 ],
    ["CSCI264", "Comp. Structure & Assembly Language", 4, "", "Core", 100, "spring",2 ],
    ["CSCI347", "Computer Architecture I", 3, "CSCI258,CSCI264", "Core", 100, "spring",3 ],
    ["CSCI344", "Programming Languages", 3, "CSCI258", "Core", 100, "spring",3],
    ["CSCI373", "Software Engineering", 3, "CSCI258", "Core", 100, "spring",3],
    ["CSCI398", "Research Topics", 1, "", "Core", 100, "spring",3],
    ["CSCI451", "Operating Systems I", 3, "CSCI258", "Core",100, "fall",4],
    ["CSCI408", "Senior Project I", 2, "CSCI398", "Core",100, "fall",4],
    ["CSCI409", "Senior Project II", 2, "CSCI408", "Core",100, "spring",4],
    ["MATH151", "Elementary Discrete Mathematics I", 3, "", "Math",100, "both",1],
    ["MATH152", "Elementary Discrete Mathematics II", 3, "MATH151", "Math",100, "both",1],
    ["MATH141", "Calculus I", 4, "", "Math",100, "both",1],#pre-req: score on placement test or MATH-120
    ["MATH142", "Calculus II", 4, "MATH141", "Math",100, "both",1],
    ["MATH273", "Introduction to Probability", 3, "MATH142", "Math",100, "both",4],
    ["PHYS111", "Physics of Digital Circuits", 2, "", "Physics",100, "fall",2],
    ["PHYS141", "College Physics I", 4, "", "Physics",100, "fall",3],
    ["PHYS143", "College Physics I Lab", 1, "PHYS141", "Physics",100, "fall",3],
    ["PHYS142", "College Physics II", 4, "PHYS141", "Physics",100, "spring",3],
    ["PHYS144", "College Physics II Lab", 1, "PHYS142", "Physics",100, "spring",3],
    ["PHIL120", "Symbolic Logic", 3, "", "Philosophy",100, "both",2],
    ["ASC101", "Thinking Through", 3, "", "Gen Ed",100, "both",1],
    ["ASC401", "Transformations Capstone", 3, "", "Gen Ed",100, "both",4], #need at least 90 completed credits/dean approval
    ["ENGL101", "Reading, Thinking and Writing", 3, "", "Gen Ed",100, "fall",1],
    # (CS) Electives with prerequisites
    ["CSCI391", "Practical Cryptology", 3, "CSCI151, MATH151, PHIL120", " Security Elective",66, "spring",2],
    ["CSCI392", "Network and Computer Security", 3, "CSCI391, CSCI257", "Security Elective",57, "fall",3],
    ["CSCI348", "Computer Architecture II", 3, "CSCI347", "Systems/Theory Elective",5,"fall",3],
    ["CSCI452", "OSs II", 3, "CSCI451", "Systems/Theory Elective",1, "spring",4],
    ["CSCI355", "Artificial Intelligence I", 3, "CSCI258, PHIL120", "AI Elective",55, "fall",4],
    ["CSCI381", "Computer Network I", 3, "CSCI152", "Systems/Theory Elective",18, "fall",2],
    ["CSCI356", "Artificial Intelligence II", 3, "CSCI355", "AI Elective",13,"spring",4],
    ["CSCI382", "Computer Networking II", 3, "CSCI381", "Systems/Theory Elective",9,"spring",2],
    ["CSCI311", "Mobile App Development", 3, "CSCI258", "Development Elective",43.75,"spring",3],
    ["CSCI434", "Database Systems I", 3, "CSCI258", "Data Elective",77, "fall",3],
    ["CSCI435", "Database Systems II", 3, "CSCI434", " Data Elective",74, "spring",3],
    ["CSCI349", "Parallel Computing", 3, "CSCI258", "Systems/Theory based Elective",60,"fall",3],
    ["CSCI350", "Parallel Computing II", 3, "CSCI349", "Systems/Theory Elective",50,"spring",3],
    ["CSCI371", "Computer Graphics (I)", 3, "CSCI258", "Development Elective",72,"fall",3],
    ["CSCI372", "Computer Graphics 2", 3, "CSCI371","Development Elective", 70, "spring",3],
    ["CSCI375", "Game Design & Programming",3,"CSCI257","Gaming Elective", 74,"fall",3],
    ["CSCI376", "Game Design & Programming 2",3, "CSCI375", "Gaming Elective", 71,"spring",3],
    ["CSCI393", "Computer Forensics",3,"MATH151, PHIL120", "Security Elective", 75,"spring",2]
]

# Convert to DataFrame
df = pd.DataFrame(courses, columns=["CourseID", "Course Name", "Credits", "Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392", "Category", "Popularity Score", "Semester Offered", "Typical Year Recommended"])
df["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"] = df["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"].fillna("")
df.to_csv("computer_science_courses.csv", index=False)
#df
# Save as CSV file
csv_filename = "computer_science_courses.csv"
df.to_csv(csv_filename, index=False)

# Return the file path for downloading
csv_filename
# Out:
# 'computer_science_courses.csv'

# %%
df
# Out:
#    CourseID                          Course Name  Credits  \
# 0   CSCI151          Intro to Computer Science I        4
# 1   CSCI152         Intro to Computer Science II        4
# 2   CSCI257          Object-Oriented Programming        4
# 3   CSCI258       Data Structures and Algorithms        4
# 4   CSCI264  Comp. Structure & Assembly Language        4
# 5   CSCI347              Computer Architecture I        3
# 6   CSCI344                Programming Languages        3
# 7   CSCI373                 Software Engineering        3
# 8   CSCI398                      Research Topics        1
# 9   CSCI451                  Operating Systems I        3
# 10  CSCI408                     Senior Project I        2
# 11  CSCI409                    Senior Project II        2
# 12  MATH151    Elementary Discrete Mathematics I        3
# 13  MATH152   Elementary Discrete Mathematics II        3
# 14  MATH141                           Calculus I        4
# 15  MATH142                          Calculus II        4
# 16  MATH273          Introduction to Probability        3
# 17  PHYS111          Physics of Digital Circuits        2
# 18  PHYS141                    College Physics I        4
# 19  PHYS143                College Physics I Lab        1
# 20  PHYS142                   College Physics II        4
# 21  PHYS144               College Physics II Lab        1
# 22  PHIL120                       Symbolic Logic        3
# 23   ASC101                     Thinking Through        3
# 24   ASC401             Transformations Capstone        3
# 25  ENGL101        Reading, Thinking and Writing        3
# 26  CSCI391                 Practical Cryptology        3
# 27  CSCI392        Network and Computer Security        3
# 28  CSCI348             Computer Architecture II        3
# 29  CSCI452                               OSs II        3
# 30  CSCI355            Artificial Intelligence I        3
# 31  CSCI381                   Computer Network I        3
# 32  CSCI356           Artificial Intelligence II        3
# 33  CSCI382               Computer Networking II        3
# 34  CSCI311               Mobile App Development        3
# 35  CSCI434                   Database Systems I        3
# 36  CSCI435                  Database Systems II        3
# 37  CSCI349                   Parallel Computing        3
# 38  CSCI350                Parallel Computing II        3
# 39  CSCI371                Computer Graphics (I)        3
# 40  CSCI372                  Computer Graphics 2        3
# 41  CSCI375            Game Design & Programming        3
# 42  CSCI376          Game Design & Programming 2        3
# 43  CSCI393                   Computer Forensics        3
#
#    Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392  \
# 0
# 1                                             CSCI151
# 2                                             CSCI152
# 3                                             CSCI257
# 4
# 5                                     CSCI258,CSCI264
# 6                                             CSCI258
# 7                                             CSCI258
# 8
# 9                                             CSCI258
# 10                                            CSCI398
# 11                                            CSCI408
# 12
# 13                                            MATH151
# 14
# 15                                            MATH141
# 16                                            MATH142
# 17
# 18
# 19                                            PHYS141
# 20                                            PHYS141
# 21                                            PHYS142
# 22
# 23
# 24
# 25
# 26                          CSCI151, MATH151, PHIL120
# 27                                   CSCI391, CSCI257
# 28                                            CSCI347
# 29                                            CSCI451
# 30                                   CSCI258, PHIL120
# 31                                            CSCI152
# 32                                            CSCI355
# 33                                            CSCI381
# 34                                            CSCI258
# 35                                            CSCI258
# 36                                            CSCI434
# 37                                            CSCI258
# 38                                            CSCI349
# 39                                            CSCI258
# 40                                            CSCI371
# 41                                            CSCI257
# 42                                            CSCI375
# 43                                   MATH151, PHIL120
#
#                          Category  Popularity Score Semester Offered  \
# 0                            Core            100.00             fall
# 1                            Core            100.00           spring
# 2                            Core            100.00             fall
# 3                            Core            100.00           spring
# 4                            Core            100.00           spring
# 5                            Core            100.00           spring
# 6                            Core            100.00           spring
# 7                            Core            100.00           spring
# 8                            Core            100.00           spring
# 9                            Core            100.00             fall
# 10                           Core            100.00             fall
# 11                           Core            100.00           spring
# 12                           Math            100.00             both
# 13                           Math            100.00             both
# 14                           Math            100.00             both
# 15                           Math            100.00             both
# 16                           Math            100.00             both
# 17                        Physics            100.00             fall
# 18                        Physics            100.00             fall
# 19                        Physics            100.00             fall
# 20                        Physics            100.00           spring
# 21                        Physics            100.00           spring
# 22                     Philosophy            100.00             both
# 23                         Gen Ed            100.00             both
# 24                         Gen Ed            100.00             both
# 25                         Gen Ed            100.00             fall
# 26              Security Elective             66.00           spring
# 27              Security Elective             57.00             fall
# 28        Systems/Theory Elective              5.00             fall
# 29        Systems/Theory Elective              1.00           spring
# 30                    AI Elective             55.00             fall
# 31        Systems/Theory Elective             18.00             fall
# 32                    AI Elective             13.00           spring
# 33        Systems/Theory Elective              9.00           spring
# 34           Development Elective             43.75           spring
# 35                  Data Elective             77.00             fall
# 36                  Data Elective             74.00           spring
# 37  Systems/Theory based Elective             60.00             fall
# 38        Systems/Theory Elective             50.00           spring
# 39           Development Elective             72.00             fall
# 40           Development Elective             70.00           spring
# 41                Gaming Elective             74.00             fall
# 42                Gaming Elective             71.00           spring
# 43              Security Elective             75.00           spring
#
#     Typical Year Recommended
# 0                          1
# 1                          1
# 2                          2
# 3                          2
# 4                          2
# 5                          3
# 6                          3
# 7                          3
# 8                          3
# 9                          4
# 10                         4
# 11                         4
# 12                         1
# 13                         1
# 14                         1
# 15                         1
# 16                         4
# 17                         2
# 18                         3
# 19                         3
# 20                         3
# 21                         3
# 22                         2
# 23                         1
# 24                         4
# 25                         1
# 26                         2
# 27                         3
# 28                         3
# 29                         4
# 30                         4
# 31                         2
# 32                         4
# 33                         2
# 34                         3
# 35                         3
# 36                         3
# 37                         3
# 38                         3
# 39                         3
# 40                         3
# 41                         3
# 42                         3
# 43                         2

# %%
# %pip install networkx scikit-learn graphviz

import networkx as nx
import matplotlib.pyplot as plt
import sklearn as sk
import graphviz

#pd.read_csv('computer_science_courses.csv')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: networkx in /home/virdeep/.local/lib/python3.10/site-packages (3.4.2)
# Requirement already satisfied: scikit-learn in /home/virdeep/.local/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: graphviz in /home/virdeep/.local/lib/python3.10/site-packages (0.20.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/virdeep/.local/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/virdeep/.local/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/lib/python3/dist-packages (from scikit-learn) (1.8.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/virdeep/.local/lib/python3.10/site-packages (from scikit-learn) (1.23.0)
# Note: you may need to restart the kernel to use updated packages.
# /home/virdeep/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
print(df.isna().sum())
# Out:
# CourseID                                                                     0
# Course Name                                                                  0
# Credits                                                                      0
# Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392    0
# Category                                                                     0
# Popularity Score                                                             0
# Semester Offered                                                             0
# Typical Year Recommended                                                     0
# dtype: int64

# %%
df["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"] = df["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"].astype(str)

# Print a sample of the column to confirm
print(df[["CourseID", "Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"]].head(10))
# Out:
#   CourseID  \
# 0  CSCI151
# 1  CSCI152
# 2  CSCI257
# 3  CSCI258
# 4  CSCI264
# 5  CSCI347
# 6  CSCI344
# 7  CSCI373
# 8  CSCI398
# 9  CSCI451
#
#   Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392
# 0
# 1                                            CSCI151
# 2                                            CSCI152
# 3                                            CSCI257
# 4
# 5                                    CSCI258,CSCI264
# 6                                            CSCI258
# 7                                            CSCI258
# 8
# 9                                            CSCI258

# %%
print(df["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"].apply(lambda x: f"[{x}]" if x == "" else x).head(10))
# Out:
# 0                 []
# 1            CSCI151
# 2            CSCI152
# 3            CSCI257
# 4                 []
# 5    CSCI258,CSCI264
# 6            CSCI258
# 7            CSCI258
# 8                 []
# 9            CSCI258
# Name: Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392, dtype: object

# %%
df = pd.read_csv("computer_science_courses.csv")
df["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"] = df["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"].fillna("")  # Replace NaN with empty string
df["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"] = df["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"].apply(lambda x: x.strip() if isinstance(x, str) else "")
course_dag = nx.DiGraph() #initialized a Directed Graph
#df
# Add nodes (Courses)
for course in df["CourseID"]:
    course_dag.add_node(course)

# Add edges (Prerequisite relationships)
for _, row in df.iterrows():
    course = row["CourseID"]
    prerequisites = (row["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"]).split(",")  # Handle multiple prereqs
    
    #debug
    print(f"Course: {course} | Prerequisites: {prerequisites}") 

    for prereq in prerequisites:
        prereq = prereq.strip()
        print(f"Checking prerequisite: '{prereq}'")
        if prereq and prereq in course_dag.nodes:  # Ensure valid prereq
            course_dag.add_edge(prereq, course)
            print(f"Added edge: {prereq} -> {course}")
        elif not prereq:
            print(f"No prerequisites for {course}, skipping edge creation.")
        else:
            # Debug: Print invalid prerequisites that are not in the DAG
            #if prereq:
                #print(f"Skipping invalid prereq: {prereq} for course: {course}")
            # Debug: Print the issue if prereq doesn't match an existing course
            print(f"Skipping invalid prereq: {prereq} for course: {course}")
            # Print all course nodes to verify if prereq matches
            print(f"Available courses: {list(course_dag.nodes)}")
# DAG visual
plt.figure(figsize=(18, 11))
pos = nx.spring_layout(course_dag, k=1, seed=42, scale=2)  # Layout for better spacing
nx.draw(course_dag, pos, with_labels=True, node_color="gold", edge_color="lightblue", node_size=1500, font_size=10)
plt.title(" CS's Student Course Pre-requisite DAG")
plt.show()

# Debug: Print all edges
print(f"Edges in the DAG: {list(course_dag.edges())}")
# Out:
# Course: CSCI151 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for CSCI151, skipping edge creation.
# Course: CSCI152 | Prerequisites: ['CSCI151']
# Checking prerequisite: 'CSCI151'
# Added edge: CSCI151 -> CSCI152
# Course: CSCI257 | Prerequisites: ['CSCI152']
# Checking prerequisite: 'CSCI152'
# Added edge: CSCI152 -> CSCI257
# Course: CSCI258 | Prerequisites: ['CSCI257']
# Checking prerequisite: 'CSCI257'
# Added edge: CSCI257 -> CSCI258
# Course: CSCI264 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for CSCI264, skipping edge creation.
# Course: CSCI347 | Prerequisites: ['CSCI258', 'CSCI264']
# Checking prerequisite: 'CSCI258'
# Added edge: CSCI258 -> CSCI347
# Checking prerequisite: 'CSCI264'
# Added edge: CSCI264 -> CSCI347
# Course: CSCI344 | Prerequisites: ['CSCI258']
# Checking prerequisite: 'CSCI258'
# Added edge: CSCI258 -> CSCI344
# Course: CSCI373 | Prerequisites: ['CSCI258']
# Checking prerequisite: 'CSCI258'
# Added edge: CSCI258 -> CSCI373
# Course: CSCI398 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for CSCI398, skipping edge creation.
# Course: CSCI451 | Prerequisites: ['CSCI258']
# Checking prerequisite: 'CSCI258'
# Added edge: CSCI258 -> CSCI451
# Course: CSCI408 | Prerequisites: ['CSCI398']
# Checking prerequisite: 'CSCI398'
# Added edge: CSCI398 -> CSCI408
# Course: CSCI409 | Prerequisites: ['CSCI408']
# Checking prerequisite: 'CSCI408'
# Added edge: CSCI408 -> CSCI409
# Course: MATH151 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for MATH151, skipping edge creation.
# Course: MATH152 | Prerequisites: ['MATH151']
# Checking prerequisite: 'MATH151'
# Added edge: MATH151 -> MATH152
# Course: MATH141 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for MATH141, skipping edge creation.
# Course: MATH142 | Prerequisites: ['MATH141']
# Checking prerequisite: 'MATH141'
# Added edge: MATH141 -> MATH142
# Course: MATH273 | Prerequisites: ['MATH142']
# Checking prerequisite: 'MATH142'
# Added edge: MATH142 -> MATH273
# Course: PHYS111 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for PHYS111, skipping edge creation.
# Course: PHYS141 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for PHYS141, skipping edge creation.
# Course: PHYS143 | Prerequisites: ['PHYS141']
# Checking prerequisite: 'PHYS141'
# Added edge: PHYS141 -> PHYS143
# Course: PHYS142 | Prerequisites: ['PHYS141']
# Checking prerequisite: 'PHYS141'
# Added edge: PHYS141 -> PHYS142
# Course: PHYS144 | Prerequisites: ['PHYS142']
# Checking prerequisite: 'PHYS142'
# Added edge: PHYS142 -> PHYS144
# Course: PHIL120 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for PHIL120, skipping edge creation.
# Course: ASC101 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for ASC101, skipping edge creation.
# Course: ASC401 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for ASC401, skipping edge creation.
# Course: ENGL101 | Prerequisites: ['']
# Checking prerequisite: ''
# No prerequisites for ENGL101, skipping edge creation.
# Course: CSCI391 | Prerequisites: ['CSCI151', ' MATH151', ' PHIL120']
# Checking prerequisite: 'CSCI151'
# Added edge: CSCI151 -> CSCI391
# Checking prerequisite: 'MATH151'
# Added edge: MATH151 -> CSCI391
# Checking prerequisite: 'PHIL120'
# Added edge: PHIL120 -> CSCI391
# Course: CSCI392 | Prerequisites: ['CSCI391', ' CSCI257']
# Checking prerequisite: 'CSCI391'
# Added edge: CSCI391 -> CSCI392
# Checking prerequisite: 'CSCI257'
# Added edge: CSCI257 -> CSCI392
# Course: CSCI348 | Prerequisites: ['CSCI347']
# Checking prerequisite: 'CSCI347'
# Added edge: CSCI347 -> CSCI348
# Course: CSCI452 | Prerequisites: ['CSCI451']
# Checking prerequisite: 'CSCI451'
# Added edge: CSCI451 -> CSCI452
# Course: CSCI355 | Prerequisites: ['CSCI258', ' PHIL120']
# Checking prerequisite: 'CSCI258'
# Added edge: CSCI258 -> CSCI355
# Checking prerequisite: 'PHIL120'
# Added edge: PHIL120 -> CSCI355
# Course: CSCI381 | Prerequisites: ['CSCI152']
# Checking prerequisite: 'CSCI152'
# Added edge: CSCI152 -> CSCI381
# Course: CSCI356 | Prerequisites: ['CSCI355']
# Checking prerequisite: 'CSCI355'
# Added edge: CSCI355 -> CSCI356
# Course: CSCI382 | Prerequisites: ['CSCI381']
# Checking prerequisite: 'CSCI381'
# Added edge: CSCI381 -> CSCI382
# Course: CSCI311 | Prerequisites: ['CSCI258']
# Checking prerequisite: 'CSCI258'
# Added edge: CSCI258 -> CSCI311
# Course: CSCI434 | Prerequisites: ['CSCI258']
# Checking prerequisite: 'CSCI258'
# Added edge: CSCI258 -> CSCI434
# Course: CSCI435 | Prerequisites: ['CSCI434']
# Checking prerequisite: 'CSCI434'
# Added edge: CSCI434 -> CSCI435
# Course: CSCI349 | Prerequisites: ['CSCI258']
# Checking prerequisite: 'CSCI258'
# Added edge: CSCI258 -> CSCI349
# Course: CSCI350 | Prerequisites: ['CSCI349']
# Checking prerequisite: 'CSCI349'
# Added edge: CSCI349 -> CSCI350
# Course: CSCI371 | Prerequisites: ['CSCI258']
# Checking prerequisite: 'CSCI258'
# Added edge: CSCI258 -> CSCI371
# Course: CSCI372 | Prerequisites: ['CSCI371']
# Checking prerequisite: 'CSCI371'
# Added edge: CSCI371 -> CSCI372
# Course: CSCI375 | Prerequisites: ['CSCI257']
# Checking prerequisite: 'CSCI257'
# Added edge: CSCI257 -> CSCI375
# Course: CSCI376 | Prerequisites: ['CSCI375']
# Checking prerequisite: 'CSCI375'
# Added edge: CSCI375 -> CSCI376
# Course: CSCI393 | Prerequisites: ['MATH151', ' PHIL120']
# Checking prerequisite: 'MATH151'
# Added edge: MATH151 -> CSCI393
# Checking prerequisite: 'PHIL120'
# Added edge: PHIL120 -> CSCI393
# Edges in the DAG: [('CSCI151', 'CSCI152'), ('CSCI151', 'CSCI391'), ('CSCI152', 'CSCI257'), ('CSCI152', 'CSCI381'), ('CSCI257', 'CSCI258'), ('CSCI257', 'CSCI392'), ('CSCI257', 'CSCI375'), ('CSCI258', 'CSCI347'), ('CSCI258', 'CSCI344'), ('CSCI258', 'CSCI373'), ('CSCI258', 'CSCI451'), ('CSCI258', 'CSCI355'), ('CSCI258', 'CSCI311'), ('CSCI258', 'CSCI434'), ('CSCI258', 'CSCI349'), ('CSCI258', 'CSCI371'), ('CSCI264', 'CSCI347'), ('CSCI347', 'CSCI348'), ('CSCI398', 'CSCI408'), ('CSCI451', 'CSCI452'), ('CSCI408', 'CSCI409'), ('MATH151', 'MATH152'), ('MATH151', 'CSCI391'), ('MATH151', 'CSCI393'), ('MATH141', 'MATH142'), ('MATH142', 'MATH273'), ('PHYS141', 'PHYS143'), ('PHYS141', 'PHYS142'), ('PHYS142', 'PHYS144'), ('PHIL120', 'CSCI391'), ('PHIL120', 'CSCI355'), ('PHIL120', 'CSCI393'), ('CSCI391', 'CSCI392'), ('CSCI355', 'CSCI356'), ('CSCI381', 'CSCI382'), ('CSCI434', 'CSCI435'), ('CSCI349', 'CSCI350'), ('CSCI371', 'CSCI372'), ('CSCI375', 'CSCI376')]

# %%
#print(f"Edges in the DAG: {list(course_dag.edges())}")

# %%
import random
import numpy as np
df_courses = pd.DataFrame(courses, columns=["CourseID", "Course Name", "Credits", "Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392", "Category", "Popularity Score", "Semester Offered", "Typical Year Recommended"])

def generate_student_data(num_students, courses_df):
    student_data = []
    course_ids = courses_df["CourseID"].tolist()
    semesters = ["fall", "spring"]
    years = [1, 2, 3, 4]
    
    for student_id in range(num_students):
        completed_courses = random.sample(course_ids, random.randint(5, 10))  # Random courses completed
        current_year = random.choice(years)  # Random year
        current_semester = random.choice(semesters)  # Random semester
        
        student_data.append({
            "StudentID": f"S{student_id+1}",
            "CompletedCourses": completed_courses,
            "CurrentYear": current_year,
            "CurrentSemester": current_semester
        })
    
    return pd.DataFrame(student_data)

# Generate random student data
students_df = generate_student_data(num_students=20, courses_df=df_courses)

# Function to recommend courses based on completed courses, current semester, and year
def recommend_courses(student_row, df_courses):
    completed_courses = student_row["CompletedCourses"]
    current_year = student_row["CurrentYear"]
    current_semester = student_row["CurrentSemester"]
    
    available_courses = []
    
    for _, row in df_courses.iterrows():
        course = row["CourseID"]
        prerequisites = row["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"].split(",") if row["Prerequisites/Concurrent PHYS Lab/Possible CS257 (or 58) Co-req for CS392"] else []
        semester_offered = row["Semester Offered"]
        typical_year = row["Typical Year Recommended"]
        
        if all(prereq in completed_courses for prereq in prerequisites):
            if (typical_year == current_year or typical_year == "both") and (semester_offered == current_semester or semester_offered == "both"):
                available_courses.append(course)
    
    return available_courses

# Example: Recommend courses for each student
students_df["RecommendedCourses"] = students_df.apply(lambda row: recommend_courses(row, df_courses), axis=1)
print(students_df[["StudentID", "CompletedCourses", "RecommendedCourses"]])
pd.set_option('display.max_colwidth', None)
print(students_df[["StudentID", "CurrentYear"]])
# Out:
#    StudentID  \
# 0         S1
# 1         S2
# 2         S3
# 3         S4
# 4         S5
# 5         S6
# 6         S7
# 7         S8
# 8         S9
# 9        S10
# 10       S11
# 11       S12
# 12       S13
# 13       S14
# 14       S15
# 15       S16
# 16       S17
# 17       S18
# 18       S19
# 19       S20
#
#                                                                               CompletedCourses  \
# 0                     [CSCI409, CSCI392, PHYS142, PHYS143, CSCI435, CSCI355, MATH141, CSCI356]
# 1   [CSCI355, MATH273, CSCI347, PHYS141, CSCI398, CSCI392, CSCI371, PHYS144, CSCI152, CSCI373]
# 2            [PHYS142, MATH152, CSCI398, ENGL101, MATH141, CSCI393, CSCI355, CSCI349, CSCI434]
# 3                     [MATH152, CSCI452, PHYS144, CSCI409, CSCI408, CSCI382, MATH273, MATH141]
# 4   [CSCI311, CSCI408, MATH141, CSCI371, CSCI393, CSCI373, CSCI347, PHIL120, PHYS143, CSCI348]
# 5            [CSCI376, PHYS141, CSCI348, CSCI434, CSCI264, CSCI152, CSCI452, PHYS111, CSCI258]
# 6    [CSCI372, ASC401, CSCI344, CSCI355, PHYS144, PHIL120, CSCI376, CSCI392, CSCI435, PHYS142]
# 7                                                 [CSCI355, CSCI398, ASC101, PHYS141, MATH152]
# 8                              [PHYS142, CSCI257, CSCI391, CSCI152, CSCI435, PHYS141, CSCI151]
# 9            [MATH152, MATH141, CSCI257, CSCI258, CSCI451, CSCI381, CSCI409, CSCI311, CSCI408]
# 10                                       [CSCI398, ASC401, CSCI434, PHYS141, CSCI373, MATH273]
# 11  [MATH151, CSCI409, CSCI373, CSCI392, PHYS144, CSCI382, MATH141, CSCI350, CSCI264, CSCI452]
# 12  [CSCI398, CSCI392, CSCI381, ENGL101, PHYS143, CSCI355, PHYS144, MATH273, CSCI151, PHYS111]
# 13           [MATH151, CSCI409, CSCI408, CSCI372, CSCI435, ENGL101, CSCI376, PHYS111, CSCI258]
# 14                                               [CSCI371, CSCI264, PHIL120, CSCI375, CSCI435]
# 15                     [MATH151, ASC101, CSCI349, CSCI356, CSCI435, CSCI391, PHYS111, CSCI152]
# 16                     [ASC401, CSCI381, CSCI356, CSCI409, CSCI347, CSCI435, CSCI451, CSCI258]
# 17                                               [CSCI375, MATH141, PHYS144, CSCI435, CSCI264]
# 18  [CSCI393, MATH151, CSCI372, CSCI376, CSCI344, CSCI451, CSCI434, CSCI408, MATH142, PHYS142]
# 19           [CSCI409, CSCI381, CSCI349, MATH273, CSCI452, PHYS141, MATH151, CSCI350, CSCI257]
#
#                                        RecommendedCourses
# 0                     [MATH151, MATH141, MATH142, ASC101]
# 1                                       [ASC401, CSCI356]
# 2                    [CSCI398, PHYS144, CSCI435, CSCI350]
# 3                                      [CSCI264, PHIL120]
# 4                                       [CSCI409, ASC401]
# 5            [CSCI151, MATH151, MATH141, ASC101, ENGL101]
# 6            [CSCI151, MATH151, MATH141, ASC101, ENGL101]
# 7                              [MATH151, MATH141, ASC101]
# 8                                                [ASC401]
# 9                     [MATH151, MATH141, MATH142, ASC101]
# 10                                     [PHYS141, PHYS143]
# 11                                               [ASC401]
# 12                                      [CSCI408, ASC401]
# 13                   [PHYS141, CSCI434, CSCI349, CSCI371]
# 14                             [MATH151, MATH141, ASC101]
# 15  [CSCI151, MATH151, MATH152, MATH141, ASC101, ENGL101]
# 16                             [MATH151, MATH141, ASC101]
# 17                                               [ASC401]
# 18                                     [PHYS111, PHIL120]
# 19  [CSCI151, MATH151, MATH152, MATH141, ASC101, ENGL101]
#    StudentID  CurrentYear
# 0         S1            1
# 1         S2            4
# 2         S3            3
# 3         S4            2
# 4         S5            4
# 5         S6            1
# 6         S7            1
# 7         S8            1
# 8         S9            4
# 9        S10            1
# 10       S11            3
# 11       S12            4
# 12       S13            4
# 13       S14            3
# 14       S15            1
# 15       S16            1
# 16       S17            1
# 17       S18            4
# 18       S19            2
# 19       S20            1
